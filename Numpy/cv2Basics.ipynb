# %%
import cv2 
image = None
image = cv2.imread('C:/Users/Lenovo/Desktop/Python/File Handling/focus_vs_multitask.png')
if image is None:
    print("Image not found!")
else:
    print("image loaded successfully")
# Out:
# image loaded successfully

# %%
import numpy as np
np.shape(image)  # image is stored as 3d
# Out:
# (1024, 1024, 3)

# %%
from matplotlib import pyplot as plt
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # from claude to convert deafult BGR rule to RGB (expected by pyplot)
plt.imshow(img_rgb)
plt.axis('off') # to remove side scale in x and y axis 
plt.show()

# %%
image = np.flip(image)
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
