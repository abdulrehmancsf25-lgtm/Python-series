# %% [markdown]
# **Iteration is a process to fetch item by item from an object and perform any operation on it**
# **Example**
# List ,Tuple

# %%
L = [1,2,3,4,5]
for i in L:
    print(i) # this process is called iteration
# Out:
# 1
# 2
# 3
# 4
# 5
