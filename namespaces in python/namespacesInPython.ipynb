# %% [markdown]
# **Namespaces**
# namespace is a spce that holds identifiers
# **4types**
# 1. Global
# 2. Local
# 3. Enclosing
# 4. Builtin
#
# Namespaces are dictionaries of identifiers and their objects (key,value)

# %%
a = 4
b = 3
# its namespace looks like -> {a:4 , b:3} and is global
