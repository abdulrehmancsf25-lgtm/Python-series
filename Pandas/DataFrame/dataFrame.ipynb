# %%
import numpy as np
import pandas as pd

# %%
arr = [[100,80,10],
       [90,98,14]
       ,[67,78,8],
       [56,76,7]]
pd.DataFrame(arr , columns=['IQ' , 'Marks' , 'Sallary(LPA)'])
# Out:
#     IQ  Marks  Sallary(LPA)
# 0  100     80            10
# 1   90     98            14
# 2   67     78             8
# 3   56     76             7

# %%
# using dictionary
dictioanry = {'IQ':[100 , 90 , 67 , 56],
              'Marks' : [80,98,78,76],
              'Sallary(LPA)' : [10,14,8,7]}
students = pd.DataFrame(dictioanry)

# %%
students
# Out:
#     IQ  Marks  Sallary(LPA)
# 0  100     80            10
# 1   90     98            14
# 2   67     78             8
# 3   56     76             7

# %%
# using read csv
movies = pd.read_csv('C:/Users/Lenovo/Desktop/Python/Pandas/movies.csv')

# %%
movies.sample()
# Out:
#     title_x    imdb_id                                        poster_path  \
# 154    Pihu  tt8458202  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                      wiki_link title_y original_title  \
# 154  https://en.wikipedia.org/wiki/Pihu_(film)    Pihu           Pihu
#
#      is_adult  year_of_release runtime          genres  imdb_rating  \
# 154         0             2018      91  Drama|Thriller          6.7
#
#      imdb_votes                                              story  \
# 154        1582  The social thriller starring the two year baby...
#
#                                                summary tagline  \
# 154  The social thriller starring the two year baby...     NaN
#
#                                  actors wins_nominations  \
# 154  Rahul Bagga|Pihu Myra Vishwakarma|              NaN
#
#                  release_date
# 154  16 November 2018 (India)

# %%
ipl = pd.read_csv('C:/Users/Lenovo/Desktop/Python/Pandas/ipl-matches.csv')

# %%
ipl.sample()
# Out:
#          ID        City        Date Season MatchNumber            Team1  \
# 412  980941  Chandigarh  2016-04-25   2016          21  Kings XI Punjab
#
#               Team2                                              Venue  \
# 412  Mumbai Indians  Punjab Cricket Association IS Bindra Stadium, ...
#
#           TossWinner TossDecision SuperOver     WinningTeam WonBy  Margin  \
# 412  Kings XI Punjab        field         N  Mumbai Indians  Runs    25.0
#
#     method Player_of_Match                                       Team1Players  \
# 412    NaN        PA Patel  ['M Vijay', 'M Vohra', 'SE Marsh', 'GJ Maxwell...
#
#                                           Team2Players      Umpire1    Umpire2
# 412  ['RG Sharma', 'PA Patel', 'AT Rayudu', 'JC But...  Nitin Menon  RJ Tucker

# %%
movies.shape
# Out:
# (1629, 18)

# %%
print(type(movies.dtypes))
movies.dtypes
# Out:
# <class 'pandas.Series'>
# title_x                 str
# imdb_id                 str
# poster_path             str
# wiki_link               str
# title_y                 str
# original_title          str
# is_adult              int64
# year_of_release       int64
# runtime                 str
# genres                  str
# imdb_rating         float64
# imdb_votes            int64
# story                   str
# summary                 str
# tagline                 str
# actors                  str
# wins_nominations        str
# release_date            str
# dtype: object

# %% [markdown]
# **Attributes and Methods + Functions**

# %%
#shape
ipl.shape
# Out:
# (950, 20)

# %%
# dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                   str
# Date                   str
# Season                 str
# MatchNumber            str
# Team1                  str
# Team2                  str
# Venue                  str
# TossWinner             str
# TossDecision           str
# SuperOver              str
# WinningTeam            str
# WonBy                  str
# Margin             float64
# method                 str
# Player_of_Match        str
# Team1Players           str
# Team2Players           str
# Umpire1                str
# Umpire2                str
# dtype: object

# %%
#colums -> index obj with columns names 
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='str')

# %%
# values
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
#index 
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
# ATTRIBUTES
# head
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
# tail / sample
ipl.tail(3)
ipl.sample(3)
# Out:
#           ID       City        Date Season MatchNumber  \
# 536   729309        NaN  2014-04-27   2014          16
# 319  1082645       Pune  2017-05-14   2017          55
# 734   501239  Hyderabad  2011-05-03   2011          42
#
#                       Team1                  Team2  \
# 536        Delhi Daredevils         Mumbai Indians
# 319  Rising Pune Supergiant        Kings XI Punjab
# 734         Deccan Chargers  Kolkata Knight Riders
#
#                                          Venue              TossWinner  \
# 536                    Sharjah Cricket Stadium          Mumbai Indians
# 319    Maharashtra Cricket Association Stadium  Rising Pune Supergiant
# 734  Rajiv Gandhi International Stadium, Uppal         Deccan Chargers
#
#     TossDecision SuperOver             WinningTeam    WonBy  Margin method  \
# 536          bat         N        Delhi Daredevils  Wickets     6.0    NaN
# 319        field         N  Rising Pune Supergiant  Wickets     9.0    NaN
# ...

# %%
# info  V.IMP (imp info of data)
ipl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    str
#  6   Team2            950 non-null    str
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
#  17  Team2Players     950 non-null    str
# ...

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   str
#  1   imdb_id           1629 non-null   str
#  2   poster_path       1526 non-null   str
#  3   wiki_link         1629 non-null   str
#  4   title_y           1629 non-null   str
#  5   original_title    1629 non-null   str
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   str
#  9   genres            1629 non-null   str
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   str
#  13  summary           1629 non-null   str
#  14  tagline           557 non-null    str
#  15  actors            1624 non-null   str
#  16  wins_nominations  707 non-null    str
# ...

# %%
# runs mathematical functions on numerical columns
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
# isnull
ipl.isnull()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
ipl.isnull().sum() # total null values
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
# duplicated -> duplicate rows
ipl.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Length: 950, dtype: bool

# %%
ipl.duplicated().sum()
# Out:
# np.int64(0)

# %%
# rename -> rename columns
students
# Out:
#     IQ  Marks  Sallary(LPA)
# 0  100     80            10
# 1   90     98            14
# 2   67     78             8
# 3   56     76             7

# %%
students.rename(columns={'Marks':'marks' , 'Sallary(LPA)':'Package(LPA)'}) # temporary change
# for permanant inplace=True
# Out:
#     IQ  marks  Package(LPA)
# 0  100     80            10
# 1   90     98            14
# 2   67     78             8
# 3   56     76             7

# %%
ipl.iloc[-1]
# Out:
# ID                                                            335982
# City                                                       Bangalore
# Date                                                      2008-04-18
# Season                                                       2007/08
# MatchNumber                                                        1
# Team1                                    Royal Challengers Bangalore
# Team2                                          Kolkata Knight Riders
# Venue                                          M Chinnaswamy Stadium
# TossWinner                               Royal Challengers Bangalore
# TossDecision                                                   field
# SuperOver                                                          N
# WinningTeam                                    Kolkata Knight Riders
# WonBy                                                           Runs
# Margin                                                         140.0
# ...

# %%
sum(ipl['SuperOver'] == 'Y') # matches with super overs
# Out:
# 14

# %%
ipl['WinningTeam'].unique() # check teams
# Out:
# <StringArray>
# [             'Gujarat Titans',            'Rajasthan Royals',
#  'Royal Challengers Bangalore',                'Punjab Kings',
#               'Mumbai Indians',        'Lucknow Super Giants',
#          'Sunrisers Hyderabad',              'Delhi Capitals',
#        'Kolkata Knight Riders',         'Chennai Super Kings',
#              'Kings XI Punjab',                           nan,
#             'Delhi Daredevils',      'Rising Pune Supergiant',
#                'Gujarat Lions',     'Rising Pune Supergiants',
#                'Pune Warriors',             'Deccan Chargers',
#         'Kochi Tuskers Kerala']
# Length: 19, dtype: str

# %%
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings') ]
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
((movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)).sum()
# Out:
# np.int64(43)

# %%
movies.sample(2)
# Out:
#             title_x    imdb_id  \
# 81    Vodka Diaries  tt6275262
# 698  Maximum (film)  tt2339549
#
#                                            poster_path  \
# 81   https://upload.wikimedia.org/wikipedia/en/thum...
# 698  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                         wiki_link        title_y  \
# 81    https://en.wikipedia.org/wiki/Vodka_Diaries  Vodka Diaries
# 698  https://en.wikipedia.org/wiki/Maximum_(film)        Maximum
#
#     original_title  is_adult  year_of_release runtime              genres  \
# 81   Vodka Diaries         0             2018     120    Mystery|Thriller
# 698        Maximum         0             2012     110  Action|Crime|Drama
#
#      imdb_rating  imdb_votes  \
# 81           5.6         959
# 698          4.9         187
#
#                                                  story  \
# 81   In the misty town of Manali  ACP Ashwini Dixit...
# 698  It's the story of two cops and their struggle ...
#
# ...

# %%
mask1 =movies['genres'].str.split('|').apply(lambda x : 'Action' in x)
mask2 = movies['imdb_rating'] > 7.5
movies[mask1 & mask2]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
movies['genres']
# Out:
# 0       Action|Drama|War
# 1                    War
# 2        Biography|Drama
# 3            Crime|Drama
# 4                  Drama
#               ...
# 1624               Drama
# 1625               Drama
# 1626        Comedy|Drama
# 1627              Action
# 1628       Drama|Romance
# Name: genres, Length: 1629, dtype: str

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='str')

# %%
ipl.values[0]
# Out:
# array([1312200, 'Ahmedabad', '2022-05-29', '2022', 'Final',
#        'Rajasthan Royals', 'Gujarat Titans',
#        'Narendra Modi Stadium, Ahmedabad', 'Rajasthan Royals', 'bat', 'N',
#        'Gujarat Titans', 'Wickets', 7.0, nan, 'HH Pandya',
#        "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Ashwin', 'R Parag', 'TA Boult', 'OC McCoy', 'M Prasidh Krishna', 'YS Chahal']",
#        "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#        'CB Gaffaney', 'Nitin Menon'], dtype=object)

# %%
# students
students
# Out:
#     IQ  Marks  Sallary(LPA)
# 0  100     80            10
# 1   90     98            14
# 2   67     78             8
# 3   56     76             7

# %%
students.insert( 0  , 'Name' , ['abdul' , 'hamza' , 'ali' , 'zeeshan']) # to add column at any position

# %%
students
# Out:
#       Name   IQ  Marks  Sallary(LPA)
# 0    abdul  100     80            10
# 1    hamza   90     98            14
# 2      ali   67     78             8
# 3  zeeshan   56     76             7

# %%
students.set_index('Name' , inplace=True)

# %%
students
# Out:
#           IQ  Marks  Sallary(LPA)
# Name
# abdul    100     80            10
# hamza     90     98            14
# ali       67     78             8
# zeeshan   56     76             7

# %%
students['Country'] = 'Pakistan' # adding new column to last

# %%
students
# Out:
#           IQ  Marks  Sallary(LPA)   Country
# Name
# abdul    100     80            10  Pakistan
# hamza     90     98            14  Pakistan
# ali       67     78             8  Pakistan
# zeeshan   56     76             7  Pakistan

# %%
students.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4 entries, abdul to zeeshan
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   IQ            4 non-null      int64
#  1   Marks         4 non-null      int64
#  2   Sallary(LPA)  4 non-null      int64
#  3   Country       4 non-null      str
# dtypes: int64(3), str(1)
# memory usage: 160.0+ bytes

# %%
# fetching rows
students.loc['abdul':'ali':2]
# Out:
#         IQ  Marks  Sallary(LPA)   Country
# Name
# abdul  100     80            10  Pakistan
# ali     67     78             8  Pakistan

# %%
students.iloc[0:3]
# Out:
#         IQ  Marks  Sallary(LPA)   Country
# Name
# abdul  100     80            10  Pakistan
# hamza   90     98            14  Pakistan
# ali     67     78             8  Pakistan

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# fetching both cols and rows
students.loc['abdul' , 'Marks':]
# Out:
# Marks                 80
# Sallary(LPA)          10
# Country         Pakistan
# Name: abdul, dtype: object

# %%
students.loc['abdul'::2 , 'IQ'::2]
# Out:
#         IQ  Sallary(LPA)
# Name
# abdul  100            10
# ali     67             8

# %%
# add a lead actor series at last with first actor name in actors
movies['lead actor'] = movies['actors'].str.split('|').apply(lambda x : x if type(x) == float else x[0])

# %%
movies.sample(3)
# Out:
#                   title_x    imdb_id  \
# 754  Dum Maaro Dum (film)  tt1618430
# 863       Milenge Milenge  tt0443331
# 221         Simran (film)  tt6405126
#
#                                            poster_path  \
# 754  https://upload.wikimedia.org/wikipedia/en/thum...
# 863  https://upload.wikimedia.org/wikipedia/en/7/7f...
# 221  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link          title_y  \
# 754  https://en.wikipedia.org/wiki/Dum_Maaro_Dum_(f...    Dum Maaro Dum
# 863      https://en.wikipedia.org/wiki/Milenge_Milenge  Milenge Milenge
# 221        https://en.wikipedia.org/wiki/Simran_(film)           Simran
#
#       original_title  is_adult  year_of_release runtime                genres  \
# 754    Dum Maaro Dum         0             2011     128    Action|Crime|Drama
# 863  Milenge Milenge         0             2010     109         Drama|Romance
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    str
#  6   Team2            950 non-null    str
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
#  17  Team2Players     950 non-null    str
# ...

# %%
ipl['SuperOver'] = ipl['SuperOver'].astype('category')

# %%
ipl['Umpire1'] = ipl['Umpire1'].astype('category')
ipl['Umpire2'] = ipl['Umpire2'].astype('category')
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')

# %%
# after reducing space 
ipl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    category
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
# ...
