# %%
import pandas as pd
import numpy as np

# %%
subs = pd.read_csv('C:/Users/Lenovo/Desktop/Python/Pandas/subs.csv').squeeze()

# %%
vk = pd.read_csv('C:/Users/Lenovo/Desktop/Python/Pandas/kohli_ipl.csv' ,index_col=0).squeeze()

# %%
movies  = pd.read_csv('C:/Users/Lenovo/Desktop/Python/Pandas/bollywood.csv' ,index_col='movie').squeeze()

# %% [markdown]
# **sort_values**

# %%
subs.sort_values()
# Out:
# 42      33
# 6       33
# 24      35
# 19      37
# 14      39
#       ...
# 280    295
# 233    301
# 168    306
# 331    312
# 330    396
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# want highest subscribres gained value 
print(subs.sort_values(ascending=False).head(1))
print(subs.sort_values(ascending=False).head(1).values) # numpy array 
print(subs.sort_values(ascending=False).head(1).values[0]) # value
# Out:
# 330    396
# Name: Subscribers gained, dtype: int64
# [396]
# 396

# %% [markdown]
# **sortvalues INPLACE**

# %%
subs.sort_values(inplace=True) # permanantly sorted -> not recommended

# %%
subs
# Out:
# 42      33
# 6       33
# 24      35
# 19      37
# 14      39
#       ...
# 280    295
# 233    301
# 168    306
# 331    312
# 330    396
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# movies series 
movies.sort_values() # sorts alphabetically
# Out:
# movie
# Qaidi Band                            Aadar Jain
# Roar: Tigers of the Sundarbans      Aadil Chahal
# Lipstick Under My Burkha            Aahana Kumra
# Raat Gayi Baat Gayi?                Aamir Bashir
# Talaash: The Answer Lies Within       Aamir Khan
#                                         ...
# Dil Toh Deewana Hai                  Zeenat Aman
# Sallu Ki Shaadi                      Zeenat Aman
# Strings of Passion                   Zeenat Aman
# Dunno Y... Na Jaane Kyon             Zeenat Aman
# Taj Mahal: An Eternal Love Story     Zulfi Sayed
# Name: lead, Length: 1500, dtype: str

# %%
movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# ** count method**

# %%
vk.count() # total items in series
# Out:
# np.int64(215)

# %% [markdown]
# **# sum -> product**

# %%
vk.sum() # total runs
# Out:
# np.int64(6634)

# %%
vk.prod() # due to 0 score in some match
# Out:
# np.int64(0)

# %%
subs.sum() # total subscribers
# Out:
# np.int64(49510)

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
np.percentile(subs.values , 50) # 50th percentile
# Out:
# np.float64(123.0)

# %%
movies[-2:] # last two movies in record
# Out:
# movie
# Company (film)            Ajay Devgn
# Awara Paagal Deewana    Akshay Kumar
# Name: lead, dtype: str

# %%
# VERY IMP 
# DIFF B/W SIZE & COUNT
# SIZE TELLS ALL ITEMS
# COUNT TELLS ONLY NON NAN VALUE
s = pd.Series([np.nan , 89.8 ,42.56 , 42.7])
print(s.count())
print(s.size)
# Out:
# 3
# 4

# %% [markdown]
# **Series with Python Functionalities**

# %%
print(len(subs)) # total items
# Out:
# 365

# %%
dir(subs)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
# type conversion
list(subs)
# Out:
# [33,
#  33,
#  35,
#  37,
#  39,
#  40,
#  40,
#  40,
#  40,
#  42,
#  42,
#  43,
#  44,
#  44,
#  44,
#  45,
#  46,
#  46,
#  48,
#  49,
#  49,
#  49,
#  49,
#  50,
#  50,
#  50,
#  51,
#  54,
#  56,
#  56,
#  56,
#  56,
#  57,
#  61,
#  62,
#  64,
#  65,
#  65,
#  66,
#  66,
#  66,
#  66,
#  67,
#  68,
#  70,
#  70,
#  70,
#  71,
#  71,
#  72,
#  72,
#  72,
#  72,
#  72,
#  73,
#  74,
#  74,
#  75,
#  76,
#  76,
#  76,
#  76,
#  77,
#  77,
#  78,
#  78,
#  78,
#  79,
#  79,
#  80,
#  80,
#  80,
#  81,
#  81,
#  82,
#  82,
#  83,
#  83,
#  83,
#  84,
#  84,
#  84,
#  85,
#  86,
#  86,
#  86,
#  87,
#  87,
#  87,
#  87,
#  88,
#  88,
#  88,
#  88,
#  88,
#  89,
#  89,
#  89,
#  90,
#  90,
#  90,
#  90,
#  91,
#  92,
#  92,
#  92,
#  93,
#  93,
#  93,
#  93,
#  95,
#  95,
#  96,
#  96,
#  96,
#  96,
#  97,
#  97,
#  98,
#  98,
#  99,
#  99,
#  100,
#  100,
#  100,
#  101,
#  101,
#  101,
#  102,
#  102,
#  103,
#  103,
#  104,
#  104,
#  104,
#  105,
#  105,
#  105,
#  105,
#  105,
# ...

# %%
dict(movies)
# Out:
# {'Uri: The Surgical Strike': 'Vicky Kaushal',
#  'Battalion 609': 'Vicky Ahuja',
#  'The Accidental Prime Minister (film)': 'Anupam Kher',
#  'Why Cheat India': 'Emraan Hashmi',
#  'Evening Shadows': 'Mona Ambegaonkar',
#  'Soni (film)': 'Geetika Vidya Ohlyan',
#  'Fraud Saiyaan': 'Arshad Warsi',
#  'Bombairiya': 'Radhika Apte',
#  'Manikarnika: The Queen of Jhansi': 'Kangana Ranaut',
#  'Thackeray (film)': 'Nawazuddin Siddiqui',
#  'Amavas': 'Ali Asgar',
#  'Gully Boy': 'Ranveer Singh',
#  'Hum Chaar': 'Prit Kamani',
#  'Total Dhamaal': 'Ajay Devgn',
#  'Sonchiriya': 'Sushant Singh Rajput',
#  'Badla (2019 film)': 'Amitabh Bachchan',
#  'Mard Ko Dard Nahi Hota': 'Abhimanyu Dasani',
#  'Hamid (film)': 'Talha Arshad Reshi',
#  'Photograph (film)': 'Nawazuddin Siddiqui',
#  'Risknamaa': 'Garima Agarwal',
#  'Mere Pyare Prime Minister': 'Rasika Agashe',
#  '22 Yards': 'Barun Sobti',
#  'Kesari (film)': 'Akshay Kumar',
#  'Notebook (2019 film)': 'Zaheer Iqbal',
# ...

# %% [markdown]
# **in operator by default works on index col**

# %%
' Vicky Kaushal' in movies # search in indices
# Out:
# False

# %%
'Vicky Kaushal' in movies.values
# Out:
# True

# %% [markdown]
# # Arithmetic Operators(Broadcasting)

# %%
100 + subs
# Out:
# 42     133
# 6      133
# 24     135
# 19     137
# 14     139
#       ...
# 280    395
# 233    401
# 168    406
# 331    412
# 330    496
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# Relational Operators
subs > 70 # gives boolean
# Out:
# 42     False
# 6      False
# 24     False
# 19     False
# 14     False
#        ...
# 280     True
# 233     True
# 168     True
# 331     True
# 330     True
# Name: Subscribers gained, Length: 365, dtype: bool

# %%
subs[subs > 70 ]
# Out:
# 130     71
# 104     71
# 133     72
# 57      72
# 87      72
#       ...
# 280    295
# 233    301
# 168    306
# 331    312
# 330    396
# Name: Subscribers gained, Length: 318, dtype: int64

# %%
# in how many matckes vk scored more than equal to 50
vk[vk>= 50].size
# Out:
# 50

# %%
# find number of ducks
vk [ vk == 0].size
# Out:
# 9

# %%
# find actors with more than 20 movies 
s = movies.value_counts()
s
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
s[s > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
s[s>20].plot(kind='pie')
# Out:
# <Axes: >

# %%
subs = pd.read_csv('C:/Users/Lenovo/Desktop/Python/Pandas/subs.csv').squeeze()

# %%
subs.head(20).plot(kind='bar') # first 20 days subscribers gain
# Out:
# <Axes: >

# %%
vk.plot()
# Out:
# <Axes: xlabel='match_no'>

# %%
x = pd.Series((1,2,3,4))
x[-1::-1]
# Out:
# 3    4
# 2    3
# 1    2
# 0    1
# dtype: int64

# %%
x[x>3]
# Out:
# 3    4
# dtype: int64

# %% [markdown]
# **Some imp functions**

# %%
# astype

vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk.astype('int16') # temp in series permanant in numpy.array
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int16

# %%
# between
vk.between(50,60).sum() # matches with score between 50 and 60 (both inclusive)
# Out:
# np.int64(19)

# %%
vk[vk.between(50 , 60)]
# Out:
# match_no
# 15     50
# 34     58
# 44     56
# 57     57
# 71     51
# 73     58
# 80     57
# 85     56
# 103    51
# 122    52
# 129    54
# 131    54
# 137    55
# 141    58
# 144    57
# 182    50
# 197    51
# 198    53
# 209    58
# Name: runs, dtype: int64

# %%
# clip function
vk.clip(100,150)
# Out:
# match_no
# 1      100
# 2      100
# 3      100
# 4      100
# 5      100
#       ...
# 211    100
# 212    100
# 213    100
# 214    100
# 215    100
# Name: runs, Length: 215, dtype: int64

# %%
# drop duplictaes
movies.drop_duplicates(keep='last') # all unique value series 
# keep= True by default
# Out:
# movie
# Soni (film)               Geetika Vidya Ohlyan
# Hum Chaar                          Prit Kamani
# Mard Ko Dard Nahi Hota        Abhimanyu Dasani
# Hamid (film)                Talha Arshad Reshi
# Risknamaa                       Garima Agarwal
#                                   ...
# Hum Tumhare Hain Sanam          Shah Rukh Khan
# Aankhen (2002 film)           Amitabh Bachchan
# Saathiya (film)                   Vivek Oberoi
# Company (film)                      Ajay Devgn
# Awara Paagal Deewana              Akshay Kumar
# Name: lead, Length: 566, dtype: str

# %%
vk.drop_duplicates()
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 6       9
#        ..
# 173    29
# 175    72
# 176    43
# 178    90
# 198    53
# Name: runs, Length: 78, dtype: int64

# %%
ser = pd.Series([1,2,np.nan , 4 , np.nan , 6]).squeeze()

# %%
# isnull()
ser.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
ser[ser.isnull()]
# Out:
# 2   NaN
# 4   NaN
# dtype: float64

# %%
# dropna
ser.dropna()
# Out:
# 0    1.0
# 1    2.0
# 3    4.0
# 5    6.0
# dtype: float64

# %%
ser.fillna(ser.mean())
# Out:
# 0    1.00
# 1    2.00
# 2    3.25
# 3    4.00
# 4    3.25
# 5    6.00
# dtype: float64

# %%
# apply
# we want movie actors first name 
movies.sample(1)
# Out:
# movie
# Shaadi Karke Phas Gaya Yaar    Salman Khan
# Name: lead, dtype: str

# %%
# .split() to split name 
# [:-1] to get name till last word
# .join to make string again 
movies.apply(lambda x :' '.join(x.split()[:-1]) )
# Out:
# movie
# Uri: The Surgical Strike                    Vicky
# Battalion 609                               Vicky
# The Accidental Prime Minister (film)       Anupam
# Why Cheat India                            Emraan
# Evening Shadows                              Mona
#                                           ...
# Hum Tumhare Hain Sanam                  Shah Rukh
# Aankhen (2002 film)                       Amitabh
# Saathiya (film)                             Vivek
# Company (film)                               Ajay
# Awara Paagal Deewana                       Akshay
# Name: lead, Length: 1500, dtype: str

# %%
# similarly last name
movies.apply(lambda x : x.split()[-1])
# Out:
# movie
# Uri: The Surgical Strike                    Kaushal
# Battalion 609                                 Ahuja
# The Accidental Prime Minister (film)           Kher
# Why Cheat India                              Hashmi
# Evening Shadows                         Ambegaonkar
#                                            ...
# Hum Tumhare Hain Sanam                         Khan
# Aankhen (2002 film)                        Bachchan
# Saathiya (film)                              Oberoi
# Company (film)                                Devgn
# Awara Paagal Deewana                          Kumar
# Name: lead, Length: 1500, dtype: str

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# want subscriber series with more than less than 100 
new_subs = subs.apply(lambda x : 'more than 100' if x > 100 else 'less than 100' if x < 100 else 'equal to 100')
new_subs
# Out:
# 0      less than 100
# 1      less than 100
# 2      less than 100
# 3      less than 100
# 4      less than 100
#            ...
# 360    more than 100
# 361    more than 100
# 362    more than 100
# 363    more than 100
# 364    more than 100
# Name: Subscribers gained, Length: 365, dtype: str

# %%
new_subs == 'equal to 100'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 360    False
# 361    False
# 362    False
# 363    False
# 364    False
# Name: Subscribers gained, Length: 365, dtype: bool

# %%
type(ser)
# Out:
# pandas.Series

# %%
x = ser.head(3)
x[0] = 100

# %%
# in older versions pandas checge original ser when its vew variable change something 
# now pandas create new series obj when view of original one is changed

# %%
x
# Out:
# 0    100.0
# 1      2.0
# 2      NaN
# dtype: float64
