# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Titanic Dataset

# %%
df = pd.read_csv('C:/Users/Lenovo/Desktop/Python/Pandas/Group By/Titanic_dataset.csv')

# %% [markdown]
# **.str** string accessor to apply vectorized string operations in pandas

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df['Name'].str.upper()
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: str

# %%
df['Name'].str.title()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: str

# %%
df['Name'].str.strip() # remove trailing spaces
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: str

# %% [markdown]
# ** make three columns of surname , title and first_name of people(Name col) in df**

# %%
df['Name'].str.split(',').str.get(1).str.strip()
# Out:
# 0                                 Mr. Owen Harris
# 1      Mrs. John Bradley (Florence Briggs Thayer)
# 2                                     Miss. Laina
# 3              Mrs. Jacques Heath (Lily May Peel)
# 4                               Mr. William Henry
#                           ...
# 886                                   Rev. Juozas
# 887                          Miss. Margaret Edith
# 888                Miss. Catherine Helen "Carrie"
# 889                               Mr. Karl Howell
# 890                                   Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.split(',').str.get(1).str.strip().str.split(' ' ,n=1 ,expand=True) # n means how many splits 
#expand in split make a dataframe after splitting
# Out:
#          0                                      1
# 0      Mr.                            Owen Harris
# 1     Mrs.  John Bradley (Florence Briggs Thayer)
# 2    Miss.                                  Laina
# 3     Mrs.          Jacques Heath (Lily May Peel)
# 4      Mr.                          William Henry
# ..     ...                                    ...
# 886   Rev.                                 Juozas
# 887  Miss.                         Margaret Edith
# 888  Miss.               Catherine Helen "Carrie"
# 889    Mr.                            Karl Howell
# 890    Mr.                                Patrick
#
# [891 rows x 2 columns]

# %%
# NOW ADDING TO COLUMNS 
temp_df = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ' ,n=1 ,expand=True)
df['title'] = temp_df[0]
df['first_name'] = temp_df[1]

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked title  \
# 0      0  A/5 21171   7.2500   NaN        S   Mr.
# 1      0   PC 17599  71.2833   C85        C  Mrs.
#
#                               first_name
# 0                            Owen Harris
# 1  John Bradley (Florence Briggs Thayer)

# %%
# now just add the suname
df['surname'] = df['Name'].str.split(',').str.get(0)

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  title  \
# 0      0         A/5 21171   7.2500   NaN        S    Mr.
# 1      0          PC 17599  71.2833   C85        C   Mrs.
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss.
#
#                               first_name    surname
# 0                            Owen Harris     Braund
# 1  John Bradley (Florence Briggs Thayer)    Cumings
# 2                                  Laina  Heikkinen

# %%
# replace function 
df.title.value_counts() # we want to change Ms. to Miss. also Mlle. into Miss
# Out:
# title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Major.         2
# Mlle.          2
# Col.           2
# Don.           1
# Mme.           1
# Ms.            1
# Lady.          1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
df['title'] = df['title'].str.replace('Ms.'  , 'Miss.')
df['title'] = df['title'].str.replace('Mlle.'  , 'Miss.')

# %%
df.title.value_counts()
# Out:
# title
# Mr.          517
# Miss.        185
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Major.         2
# Col.           2
# Don.           1
# Mme.           1
# Lady.          1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64
