# %%
import numpy as np
import pandas as pd

# %%
ipl = pd.read_csv('C:/Users/Lenovo/Desktop/Python/Pandas/datas/ipl-matches.csv')

# %%
ipl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    str
#  6   Team2            950 non-null    str
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
#  17  Team2Players     950 non-null    str
# ...

# %%
temp_Grp_By = ipl.groupby('Season')

# %%
# filter function on group by expects a single True False to drop or retain a particular group 
type(temp_Grp_By.filter(lambda group: (group['City'] == 'Kolkata').any()))
# Out:
# pandas.DataFrame

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
movies = pd.read_csv('C:/Users/Lenovo/Desktop/Python/Pandas/datas/imdb-top-1000.csv')

# %%
movies.sample(3)
# Out:
#                           Series_Title Released_Year  Runtime      Genre  \
# 930                           Watchmen          2009      162     Action
# 247  Lagaan: Once Upon a Time in India          2001      224  Adventure
# 342                  Bohemian Rhapsody          2018      134  Biography
#
#      IMDB_Rating            Director               Star1  No_of_Votes  \
# 930          7.6         Zack Snyder  Jackie Earle Haley       500799
# 247          8.1  Ashutosh Gowariker          Aamir Khan       105036
# 342          8.0        Bryan Singer          Rami Malek       450349
#
#            Gross  Metascore
# 930  107509799.0       56.0
# 247      70147.0       84.0
# 342  216428042.0       49.0

# %%
# v.imp function pack
top_movies = (
    movies.sort_values(by=['Genre', 'IMDB_Rating'], ascending=[True, False])
    .drop_duplicates(subset='Genre', keep='first')
)

# %%
# Applying builtin aggregation fuctions on groupby objects
genres = movies.groupby('Genre')

# %%
genres.std(numeric_only=True)
# Out:
#              Runtime  IMDB_Rating    No_of_Votes         Gross  Metascore
# Genre
# Action     28.500706     0.304258  432946.814748  2.256724e+08  12.421252
# Adventure  33.317320     0.229781  301188.347642  1.697543e+08  12.345393
# Animation  14.530471     0.253221  262173.231571  2.091840e+08   8.813646
# Biography  25.514466     0.267140  271284.191372  1.363251e+08  11.028187
# Comedy     22.946213     0.228771  188653.570564  1.946513e+08  11.829160
# Crime      27.689231     0.335477  373999.730656  1.571191e+08  13.099102
# Drama      27.740490     0.267229  305554.162841  2.201164e+08  12.744687
# Family     10.606602     0.000000  137008.302816  3.048412e+08  16.970563
# Fantasy    12.727922     0.141421   22179.111299  7.606861e+07        NaN
# Film-Noir   4.000000     0.152753   54649.083277  7.048472e+07   1.527525
# Horror     13.604812     0.311302  234883.508691  9.965017e+07  15.362291
# Mystery    14.475423     0.310791  404621.915297  1.567524e+08  18.604435
# ...

# %%
genres.Gross.sum().sort_values(ascending=False).head(2)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Name: Gross, dtype: float64

# %%
# highest rated movie of each genre
movies.groupby('Genre').apply(lambda group : group.nlargest(1 ,'IMDB_Rating')).reset_index()
# Out:
#         Genre  level_1                     Series_Title Released_Year  \
# 0      Action        2                  The Dark Knight          2008
# 1   Adventure       21                     Interstellar          2014
# 2   Animation       23    Sen to Chihiro no kamikakushi          2001
# 3   Biography        7                 Schindler's List          1993
# 4      Comedy       19                     Gisaengchung          2019
# 5       Crime        1                    The Godfather          1972
# 6       Drama        0         The Shawshank Redemption          1994
# 7      Family      688       E.T. the Extra-Terrestrial          1982
# 8     Fantasy      321     Das Cabinet des Dr. Caligari          1920
# 9   Film-Noir      309                    The Third Man          1949
# 10     Horror       49                           Psycho          1960
# 11    Mystery       69                          Memento          2000
# ...

# %%
movies.nlargest(1,columns=['Metascore','IMDB_Rating'])
# Out:
#     Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 1  The Godfather          1972      175  Crime          9.2
#
#                Director          Star1  No_of_Votes        Gross  Metascore
# 1  Francis Ford Coppola  Marlon Brando      1620367  134966411.0      100.0

# %%
movies.Star1.value_counts()
# Out:
# Star1
# Tom Hanks            12
# Robert De Niro       11
# Al Pacino            10
# Clint Eastwood       10
# Leonardo DiCaprio     9
#                      ..
# Phil Harris           1
# David Hemmings        1
# John Lennon           1
# Tallulah Bankhead     1
# Robert Donat          1
# Name: count, Length: 660, dtype: int64

# %%
# TOTAL GENRES IN DATASET
movies.Genre.nunique()
# Out:
# 14

# %%
len(movies.groupby('Genre'))
# Out:
# 14

# %%
genres.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
# size 
genres.size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
genres.head(4)
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 0                             The Shawshank Redemption          1994      142
# 1                                        The Godfather          1972      175
# 2                                      The Dark Knight          2008      152
# 3                               The Godfather: Part II          1974      202
# 4                                         12 Angry Men          1957       96
# 5        The Lord of the Rings: The Return of the King          2003      201
# 6                                         Pulp Fiction          1994      154
# 7                                     Schindler's List          1993      195
# 8                                            Inception          2010      148
# 9                                           Fight Club          1999      139
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# ...
